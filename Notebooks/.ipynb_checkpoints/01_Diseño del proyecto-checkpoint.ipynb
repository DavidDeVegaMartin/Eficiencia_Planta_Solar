# %% [markdown]
# # DISEÑO DEL PROYECTO

# %% [markdown]
# # 1 - Objetivos y Palanca

# %% [markdown]
# ## 1.1. Objetivo
#
# ACME Solar Energy ha detectado comportamientos anomalos en 2 de sus plantas y se solicita al equipo de analisis de datos, que estudien los datos de los sensores y medidores para detectar, las causas. En consecuencia el Objetivo de este proyecto es:
#
# **<u>Detectar el origen de los problemas de rendimiento de las  plantas solares y si es preciso o no desplazar a las mismas a un equipo de ingenieria.</u>**
#
# ##### Requsito
#
# Identificar las palancas que determinan el rendimiento de las plantas de energia.

# %%
from IPython import display
display.Image("..//Datos/Components-of-Solar-Power-Plant.png")

# %% [markdown]
# Fuente: [https://www.electricaltechnology.org/2021/07/solar-power-plant.html]

# %% [markdown]
# **<U>Factores Clave que Impactan la Generación de Energía AC en Plantas Solares Fotovoltaicas</U>**
#
# En el marco de un proyecto de data science enfocado en optimizar la eficiencia operativa de una planta solar fotovoltaica, se identifican las siguientes variables como palancas fundamentales que afectan el objetivo de negocio: maximizar la generación de corriente alterna (AC):
#
# * **<U>Irradiación Solar</U>**:
#
#   Existe una correlación positiva entre irradiacion y generación de energía DC; sin embargo, este efecto no es lineal.
#
#   Altos niveles de irradiación pueden aumentar la temperatura de los módulos, lo cual puede reducir su rendimiento, por lo que es clave modelar este comportamiento no-monotónico.
#
# * **<u>Mantenimiento de los Paneles Fotovoltaicos:</U>**
#
#   La acumulación de suciedad, degradación de los materiales o fallos en los módulos pueden reducir significativamente la producción de energía.
#
#   Es esencial monitorear y mantener los paneles en óptimas condiciones para maximizar la generación DC.
#
# * **<u>Eficiencia de los Inversores (Inverters):</U>**
#
#    La conversión de energía DC a AC conlleva pérdidas inherentes. Minimizar estas pérdidas depende del correcto funcionamiento y la eficiencia del sistema de inversores. Fallos o degradación en estos componentes impactan directamente la cantidad de energía útil que se entrega a la red. Es un factor critico de rendimiento, un correcto mantenimiento de los mismos.
#
# * **<U>Integridad de los Sensores y Medidores:</U>**
#
#     La calidad de los datos es fundamental para cualquier análisis. Si los sensores presentan fallos o errores de medición, se pierde visibilidad sobre el desempeño real del sistema, afectando la capacidad para detectar anomalías, perdida de trazabilidad y tomar decisiones basadas en datos, que permitan la deteccion de fallos.

# %% [markdown]
# ## 1.3 KPIs
#
# En este proyecto de data science orientado a optimizar la eficiencia de conversión energética en una planta fotovoltaica, se trabajará con las siguientes variables principales:
#
# * **<u>Irradiación Solar</U>**
#
#     Representa la cantidad de energía solar incidente sobre la superficie de los paneles, medida en W/m². Es un input esencial para estimar el potencial de generación de energía.
#
# * **<U>Temperatura Ambiente y del Módulo</U>**
#
#     Ambas se registran en grados Celsius mediante sensores instalados en la planta. Son variables relevantes, ya que las altas temperaturas pueden disminuir la eficiencia de conversión de los módulos solares.
#
# * **<U>Potencia DC (Corriente Continua)</U>**
#
#   Se refiere a la potencia eléctrica generada directamente por los paneles solares antes de ser convertida. Se mide en kilovatios (kW).
#
# * **<U>Potencia AC (Corriente Alterna)</U>**
#
#     Corresponde a la potencia eléctrica entregada a la red tras la conversión de DC a AC por parte de los inversores. También se mide en kilovatios (kW).
#
# * **<U>Eficiencia del Inversor</U>**
#
#     Este indicador será calculado dentro del proyecto y refleja el rendimiento del sistema de conversión. Se define como:
#   $$
# \text{Eficiencia del inversor} = \left( \frac{\text{Potencia AC}}{\text{Potencia DC}} \right) \times 100
# $$
#
#
#     Una eficiencia alta indica una conversión óptima con mínimas pérdidas energéticas.

# %% [markdown]
# ## 1.4. Entidades y Granularidad de los datos:
#
# Para estructurar adecuadamente los datos en un proyecto de ciencia de datos enfocado en la eficiencia de una planta solar fotovoltaica, es esencial comprender la jerarquía y los componentes físicos que la conforman. Esta comprensión permite modelar las relaciones entre las entidades y facilitar análisis precisos. A continuación, se describen las principales entidades:
#
# * **<U>Célula Fotovoltaica</U>**
#
#     Unidad básica donde ocurre la conversión de la energía solar en electricidad mediante el efecto fotovoltaico.
#
# * **<U>Módulo Solar</U>**
#
#     Conjunto de células fotovoltaicas encapsuladas y conectadas eléctricamente.
#
# * **<U>Panel Solar</U>**
#
#     Agrupación de uno o varios módulos solares montados sobre una estructura común.
#
# * **<U>Array</U>**
#
#     Conjunto de paneles solares dispuestos en una configuración de filas para optimizar la captación solar.
#
# * **<u>Inversor (Inverter)</U>**
#
#     Dispositivo que recibe la corriente continua (DC) generada por los arrays y la convierte en corriente alterna (AC) para su uso o inyección a la red eléctrica.
#
# * **<U>Planta Solar</U>**
#
#     Instalación completa que puede incluir múltiples inversores, arrays, sistemas de monitoreo y conexión a la red eléctrica.
#
# * **<U>Sensores y Medidores</U>**
#
#     Dispositivos que registran variables ambientales y operativas como irradiancia, temperatura, voltaje, corriente, entre otros, proporcionando datos esenciales para el análisis de rendimiento y eficiencia.
#
#
# **<U>Granularidad de los datos</U>**
#
# * Ventanas de 15 minutos durante un periodo de 34 dias.
#
# * 2 plantas productoras
#
# * Inverters: Hay varios por planta.
#
# * Sensores:
#
#     - 1 Sensor de irradiacion por planta.
#
#     - 1 Sensor de temperatura ambiente por planta.
#
#     - 1 Sensor de temperatura del modulo por planta.

# %% [markdown]
# ## 1.5 Preguntas semilla
#
# * <u>IRRADIACION</U>
#
#     - ¿Cual es la irradiacion diaria (media,max,min)?
#
#     - ¿Que irradiacion hay en cada planta?. ¿La irradicion que hay en ambas plantas es similar?.
#
#     - ¿Como se distribuye la irradiacion a lo largo del dia?.
#
#     - ¿Es constante a lo largo de los dias? .¿Es constante en ambas plantas?. ¿Hay relacion entre irradiacion de ambas plantas?.
#
#     - ¿Como se relaciona la temperatura ambiente y la temperatura del modulo?.
#
# * <U>PLANTAS</U>
#
#     - ¿Alcanzan las misma cantidad de irradiacion?
#
#     - ¿ Que numero de arrays tiene cada planta, es similar?
#
#     - ¿Que numero de inverters tiene cada una, es similar?
#
#     - ¿Generan similar cantidad de DC? ¿y de AC?.
#
# * <U> GENERACION DE DC</U>
#
#
#     - ¿Cual es la relacion entre irradiacion y generacion de DC?.
#
#     - ¿Como se ve afectada la generacion de DC por la temperatura ambiente o del modulo?.
#
#     - ¿La generacion de DC es similar entre ambas plantas?.
#
#     - ¿ Como se distribuye la generacion de DC a lo largo del dia?.
#
#     - ¿Esta distribucion es constante a lo largo de los dias?.
#
#     - ¿Es constante a traves de todos los inverters?.
#
#     - ¿Hay picos de generacion, son constantes, se producen en ambas plantas, hay relacion entre ambas plantas?.
#
#     - ¿Hay fallos o averias en los inverters?¿Cada cuanto tiempo se producen?.
#
# * <U> GENERACION DE AC</U>
#
#
#     - ¿Cual es la relacion entre irradiacion y generacion de AC?.
#
#     - ¿Como se ve afectada la generacion de AC por la temperatura ambiente o del modulo?.
#
#     - ¿La generacion de AC es similar entre ambas plantas?.
#
#     - ¿ Como se distribuye la generacion de AC a lo largo del dia?.
#
#     - ¿Esta distribucion es constante a lo largo de los dias?.
#
#     - ¿Es constante a traves de todos los inverters?.
#
#     - ¿Hay picos de generacion, son constantes, se producen en ambas plantas, hay relacion entre ambas plantas?.
#
#     - ¿Hay fallos o averias en los inverters?¿Cada cuanto tiempo se producen?.
#
# * <u> MEDIDORES Y SENSORES</u>
#
#     - ¿Son fiables los datos de irradiacion?.
#
#     - ¿Son fiables los datos de temperatura?.
#
#     - ¿Son fiables los datos de AC y DC?.
#
#     - ¿Todos los datos anteriores son similares entre plantas?
